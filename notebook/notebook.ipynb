# %%
from langchain_core.documents import Document

# %%
doc=Document(page_content="This is the main text content i am using to create RAG",
            metadata={"source":"example.txt",
                     "pages":1,
                    "author":"Krish Naik",
                     "date_created":"2026-01-01"})
#metadata is important because it can be used as a filter!
doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Krish Naik', 'date_created': '2026-01-01'}, page_content='This is the main text content i am using to create RAG')

# %%
import os
os.makedirs("../data/text_files",exist_ok=True)

# %%
import os  # Add this at the top

sample_texts = {
    "../data/text_files/python_intro.txt": "Python is a high-level, programming language used for ml and data science web statistiques etc.."
}

for filepath, content in sample_texts.items():
    os.makedirs(os.path.dirname(filepath), exist_ok=True)  # Create folder if missing
    with open(filepath, 'w', encoding="utf-8") as f:
        f.write(content)
    print("Sample text file s created")
# Out:
# Sample text file s created

# %%
from langchain_community.document_loaders import TextLoader
loader=TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
document=loader.load()
print(document)
# Out:
# /tmp/ipykernel_5309/1850802233.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python is a high-level, programming language used for ml and data science web statistiques etc..')]

# %%
from langchain_community.document_loaders import DirectoryLoader
dir_loader=DirectoryLoader("../data/text_files",glob="**/*.txt",
                          loader_cls=TextLoader,
                          loader_kwargs={'encoding':'utf-8'},
                          show_progress=True)
documents=dir_loader.load()
documents
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 37.44it/s]
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python is a high-level, programming language used for ml and data science web statistiques etc..')]

# %%
from langchain_community.document_loaders import DirectoryLoader,PyPDFLoader,PyMuPDFLoader
dir_loader=DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf",
    loader_cls=PyMuPDFLoader,#loader class to use
    show_progress=False
)
pdf_documents=dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2015-07-25T11:25:12+02:00', 'source': '../data/pdf/Tableau_Derivees.pdf', 'file_path': '../data/pdf/Tableau_Derivees.pdf', 'total_pages': 4, 'format': 'PDF 1.5', 'title': 'Tableau de dérivées', 'author': 'Clara Parfenoff', 'subject': 'Tableau de dérivées', 'keywords': '', 'moddate': '2015-08-02T07:36:52+02:00', 'trapped': '', 'modDate': "D:20150802073652+02'00'", 'creationDate': "D:20150725112512+02'00'", 'page': 0}, page_content='Tableau de dérivées \nI) Dérivées des fonctions usuelles.  \n𝑭𝒐𝒏𝒄𝒕𝒊𝒐𝒏 𝒇∶ \n𝑫é𝒓𝒊𝒗𝒂𝒃𝒍𝒆 𝒔𝒖𝒓: \n𝑭𝒐𝒏𝒄𝒕𝒊𝒐𝒏 𝒅é𝒓𝒊𝒗é𝒆 𝒇’ ∶ \n𝒇(𝒙) = 𝒌 ( 𝒌 \uf0ce  ℝ  ) \nℝ \n𝒇’(𝒙) = 𝟎 \n𝒇(𝒙) = 𝒙 \nℝ \n𝒇’(𝒙) = 𝟏 \n𝒇(𝒙) = 𝒙𝟐 \nℝ \n𝒇’(𝒙) = 𝟐𝒙 \n𝒇(𝒙) = 𝒙 𝒏( 𝒏 \uf0ce \uf04e ) \nℝ \n𝒇’(𝒙) = 𝒏𝒙 𝒏−𝟏 \n𝒇(𝒙) =  \n𝟏\n𝒙 \n]- ∞ ; 0[∪ ]0 ; + ∞[ \n𝒇’(𝒙) = −\n𝟏\n𝒙𝟐 \n𝒇(𝒙) = √𝒙 \n]0 ; + ∞[ \n𝒇’(𝒙) = 𝟏\n𝟐√𝒙 \n𝒇(𝒙) = 𝟏\n𝒙𝒏 \nℝ∖{0} \n𝒇’(𝒙) = −\n𝒏\n𝒙𝒏+𝟏 \n𝒇(𝒙) = 𝒔𝒊𝒏(𝒙) \nℝ \n𝒇’(𝒙) = 𝒄𝒐𝒔(𝒙) \n𝒇(𝒙) 
# ...

# %%
type(pdf_documents[0])
# Out:
# langchain_core.documents.base.Document
